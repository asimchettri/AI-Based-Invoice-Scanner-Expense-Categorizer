# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('../data/sample_data.csv')
df.head()
# Out:
#        vendor               description  amount   category
# 0  Big Bazaar          Grocery purchase   245.5  groceries
# 1      Swiggy          Meal order lunch   350.0      meals
# 2        Uber            Office commute   180.0  transport
# 3      Zomato        Dinner with client   720.0      meals
# 4      Amazon  Office supplies purchase  1299.0     office

# %%
print("\nCategory counts:\n", df['category'].value_counts())
# Out:
# Category counts:
#  category
# meals        10
# office       10
# groceries     9
# transport     9
# other         2
# Name: count, dtype: int64

# %%
df['category'].value_counts().plot(kind='bar', title='Category Distribution')
plt.show()
