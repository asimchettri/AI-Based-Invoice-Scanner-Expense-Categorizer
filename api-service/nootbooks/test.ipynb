# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from utils.cleaner import *

# %%
sample_ocr = """
Your Company Inc.
1234 Company St
Invoice # 0000007
Total (USD) $2499.00
"""

print("Vendor:", guess_vendor(sample_ocr))
print("Total:", extract_total_amount(sample_ocr))
print("All Amounts:", extract_amounts(sample_ocr))
print("\nFull Metadata:\n", extract_invoice_metadata(sample_ocr))
# Out:
# Vendor: Your Company Inc.
# Total: 2499.0
# All Amounts: [2499.0, 1234.0, 7.0, 2499.0]
#
# Full Metadata:
#  {'vendor': 'Your Company Inc.', 'total': 2499.0, 'all_amounts': [2499.0, 1234.0, 7.0, 2499.0], 'cleaned_text': 'Your Company Inc.1234 Company StInvoice  0000007Total USD 2499.00', 'normalized_text': 'Your Company Inc.\n1234 Company St\nInvoice # 0000007\nTotal (USD) $2499.00', 'char_count': 74, 'line_count': 6}
